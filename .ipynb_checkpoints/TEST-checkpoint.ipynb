# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(columns=['system', 'rep', 'data','mean','std'])
data=np.array([10,20,30,40,50,60])
new_ent = pd.DataFrame({'system': 'test',
                                'rep': 1,
                                'data': data,
                                'mean': 1.4,
                                'std': 0.07,
                               })
df = pd.concat([df, new_ent])

# %%
# Out:
#   system rep data  mean   std
# 0   test   1   10   1.4  0.07
# 1   test   1   20   1.4  0.07
# 2   test   1   30   1.4  0.07
# 3   test   1   40   1.4  0.07
# 4   test   1   50   1.4  0.07
# 5   test   1   60   1.4  0.07

# %%
d = {}

d['A769'] = pd.DataFrame(columns=['t', 'rep1', 'rep2', 'rep3'],
                                         data=[[10, 0.89, 0.98, 0.31],
                                               [20, 0.34, 0.78, 0.34]]).set_index('t')

pd.concat(d, axis=1)
# Out:
#     A769
#     rep1  rep2  rep3
# t
# 10  0.89  0.98  0.31
# 20  0.34  0.78  0.34

# %%
d['PF739'] = pd.DataFrame(columns=['t', 'rep1', 'rep2', 'rep3'],
                                         data=[[10, 0.89, 0.98, 0.31],
                                               [20, 0.34, 0.78, 0.34]]).set_index('t')
pd.concat(d, axis=1)
# Out:
#     A769             PF739
#     rep1  rep2  rep3  rep1  rep2  rep3
# t
# 10  0.89  0.98  0.31  0.89  0.98  0.31
# 20  0.34  0.78  0.34  0.34  0.78  0.34

# %%
type(d)
# Out:
# dict

# %%
df = pd.concat(d, axis=1)

# %%
df
# Out:
#     A769             PF739
#     rep1  rep2  rep3  rep1  rep2  rep3
# t
# 10  0.89  0.98  0.31  0.89  0.98  0.31
# 20  0.34  0.78  0.34  0.34  0.78  0.34

# %%
df['A769']['rep1']
# Out:
# t
# 10    0.89
# 20    0.34
# Name: rep1, dtype: float64

# %%
df2 = df.copy()

# %%
df2
# Out:
#     A769             PF739
#     rep1  rep2  rep3  rep1  rep2  rep3
# t
# 10  0.89  0.98  0.31  0.89  0.98  0.31
# 20  0.34  0.78  0.34  0.34  0.78  0.34

# %%
s = {'a2b1':df, 'a2b2':df2}

# %%
new = pd.concat(s,axis=1)

# %%
new
# Out:
#     a2b1                                a2b2
#     A769             PF739              A769             PF739
#     rep1  rep2  rep3  rep1  rep2  rep3  rep1  rep2  rep3  rep1  rep2  rep3
# t
# 10  0.89  0.98  0.31  0.89  0.98  0.31  0.89  0.98  0.31  0.89  0.98  0.31
# 20  0.34  0.78  0.34  0.34  0.78  0.34  0.34  0.78  0.34  0.34  0.78  0.34

# %%
new.a2b1
# Out:
#     A769             PF739
#     rep1  rep2  rep3  rep1  rep2  rep3
# t
# 10  0.89  0.98  0.31  0.89  0.98  0.31
# 20  0.34  0.78  0.34  0.34  0.78  0.34

# %%
new['a2b1']['A769']['rep1'] = np.array([1,2])

# %%
new
# Out:
#     a2b1                                a2b2
#     A769             PF739              A769             PF739
#     rep1  rep2  rep3  rep1  rep2  rep3  rep1  rep2  rep3  rep1  rep2  rep3
# t
# 10  0.89  0.98  0.31  0.89  0.98  0.31  0.89  0.98  0.31  0.89  0.98  0.31
# 20  0.34  0.78  0.34  0.34  0.78  0.34  0.34  0.78  0.34  0.34  0.78  0.34

# %%
# create new column

inp = pd.DataFrame(columns=['t', 'rep2'],
                 data=[[10, 2.89],
                       [20, 2.34]]).set_index('t')
inp_l = pd.concat({'MT':inp}, axis=1)
inp_s = pd.concat({'a2b1':inp_l}, axis=1)


if any([(mi == inp_s.columns)[0] for mi in new.columns]):
    print("Updating values in DataFrame.")
    new.update(inp_s)
else:
    print("Adding new values to DataFrame.")
    new = new.join(inp_s)
# Out:
# Adding new values to DataFrame.

# %%
new
# Out:
#     a2b1                                a2b2                                \
#     A769             PF739              A769             PF739
#     rep1  rep2  rep3  rep1  rep2  rep3  rep1  rep2  rep3  rep1  rep2  rep3
# t
# 10  2.89  0.98  0.31  2.89  0.98  0.31  0.89  0.98  0.31  0.89  0.98  0.31
# 20  2.34  0.78  0.34  2.34  0.78  0.34  0.34  0.78  0.34  0.34  0.78  0.34
#
#     a2b1
#       MK    MT
#     rep1  rep1  rep2
# t
# 10  2.89  2.89  2.89
# 20  2.34  2.34  2.34

# %%
new.columns.sortlevel(0, sort_remaining=True)
# Out:
# (MultiIndex([('a2b1',  'A769', 'rep1'),
#              ('a2b1',  'A769', 'rep2'),
#              ('a2b1',  'A769', 'rep3'),
#              ('a2b1',    'MK', 'rep1'),
#              ('a2b1',    'MT', 'rep1'),
#              ('a2b1',    'MT', 'rep2'),
#              ('a2b1', 'PF739', 'rep1'),
#              ('a2b1', 'PF739', 'rep2'),
#              ('a2b1', 'PF739', 'rep3'),
#              ('a2b2',  'A769', 'rep1'),
#              ('a2b2',  'A769', 'rep2'),
#              ('a2b2',  'A769', 'rep3'),
#              ('a2b2', 'PF739', 'rep1'),
#              ('a2b2', 'PF739', 'rep2'),
#              ('a2b2', 'PF739', 'rep3')],
#             ),
#  array([ 0,  1,  2, 12, 13, 14,  3,  4,  5,  6,  7,  8,  9, 10, 11]))
